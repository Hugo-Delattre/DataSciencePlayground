# %% [raw]
# %conda install conda-forge::opencv

# %%
# %conda list
# Out:
# # packages in environment at /home/hugo/miniconda3/envs/pneumonie:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# absl-py                   2.2.2                    pypi_0    pypi
# alsa-lib                  1.2.13               hb9d3cd8_0    conda-forge
# anyio                     4.9.0              pyh29332c3_0    conda-forge
# argon2-cffi               23.1.0             pyhd8ed1ab_1    conda-forge
# argon2-cffi-bindings      21.2.0          py310ha75aee5_5    conda-forge
# arrow                     1.3.0              pyhd8ed1ab_1    conda-forge
# asttokens                 3.0.0              pyhd8ed1ab_1    conda-forge
# astunparse                1.6.3                    pypi_0    pypi
# async-lru                 2.0.5              pyh29332c3_0    conda-forge
# ...

# %%
# %conda install conda-forge::opencv
# Out:
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/hugo/miniconda3/envs/pneumonie
#
#   added / updated specs:
#     - conda-forge::opencv
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-2.131                 |         openblas          16 KB  conda-forge
#     blas-devel-3.9.0           |31_h1ea3ea9_openblas          16 KB  conda-forge
#     libopencv-4.11.0           |headless_py310h8ace835_4        28.9 MB  conda-forge
#     libprotobuf-5.29.3         |       h501fc15_1         3.2 MB  conda-forge
#     numpy-2.0.1                |  py310heeff2f4_1          11 KB
#     numpy-base-2.0.1           |  py310h8a23956_1         8.0 MB
#     openblas-0.3.29            |pthreads_h6ec200e_0         5.8 MB  conda-forge
# ...

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.11.0
